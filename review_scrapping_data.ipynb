# %% [markdown]
# # RATINGS PREDICTION

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
import re
import requests
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome(r'C:\Users\lenovo\Downloads\chromedriver_win32 (4)\chromedriver.exe')

# %%
url='https://www.flipkart.com/realme-narzo-50a-oxygen-blue-64-gb/product-reviews/itm81d679403c2b4?pid=MOBG6MY4UGGFQWYY&lid=LSTMOBG6MY4UGGFQWYYBVB3OV&marketplace=FLIPKART&page=2'
driver.get(url)

# %%
full_reviews=[]
ratings=[]

# %%
# fetching first pages reviews
for a in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
    full_reviews.append(a.text)
for b in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
    ratings.append(b.text)
time.sleep(1)
        #clciking on second page for reviews
driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
time.sleep(2)
        # running loop till the end of pages of all reviews
while True:
    time.sleep(2)
    for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        full_reviews.append(i.text)
    for j in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        ratings.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]/span").click()
        time.sleep(1)
    except:
        break

# %%
len(full_reviews)
# Out:
# 2834

# %%
len(ratings)
# Out:
# 2834

# %%
full_reviews
# Out:
# ["First of all thanks to flipkart for excellent service. otherwise realme narzo 50 A is realy worst one in realme series, camera quality is so poor, it's not like 50mp camera it's like 2mp camera clarity is very dull n blur, don't buy if you want good camera phone",
#  'overall good product, mobile colour is good i liked it, camera back is good front is perfect, online buying is good beneficial for me.I recommend to all that buy online fon its better , always available in color and design. Backup also nice, i ordered and received before time same product nothing damage so i am happy for this. Thanks flipkart',
#  "This mobile has good features but battery doesn't seems to be an that much good performance though having 6000 Mah others features are great and display is awesome gaming performance is also good as well so overall nice phone and only big draw back Narzo should start giving silicon case which is not provided in the box.\n\nBasic need to protect the mobile.",
#  'I GOT THIS PHONE WITH SUPERB EXCHANGE DEAL\n\nCamera is not good upto 50mp\nBattery 🔋 is very good 👍\nDisplay is HD only not sAmoled\nSpeakers sound good\nRuns very smooth no lagging 👌.\nOverall its good budget smartphone.',
#  'I gift this to my mom. The joy in her eyes tells everything. Fantabulous phone. Thanks Realme and FlipKart for bringing this wonderful phone. Packaging was superb. Easy tracking and above all... Super quick delivery. Overall 5 star from my side. Thanks!',
#  "I have used this phone continuously last 7 days from delivery\nOver all ok\nBut delivery is soo late am disappointed it's take two weeks more time\nBattery performance is. Awesome\nBut charging time is more than 2 and half hours to full slightly disappointed\nBack camera 50 mp is awesome night scape photos is good\nSelfie camera performance is average\nIt has G85 processor is best performance\nOver all phone is worth for money go for it",
#  'What a mobile amazing battery back up also. Loved to purchase from flipkart. Delivery boy is also good behaviour. Best exchange prize.i got from flipkart',
#  'Very nice phone and value for mobile..\nCamera good, battery backup is very good\nDisplay nice, and performance is well so overall\nVery good mobile.',
#  'Mobile is good battery 6000ma super camera guality Vera level performance is good phone oxygen Blue closers super',
#  'Nice phone but if you want a good display and fast charging then go for realme narzo 30.',
#  "Thanks again Flipkart team the wonderful delivery on time. Kind delivery boy.\nThis product purchased for my Mom 😍 and she is very happy gifted to mom on her birthday 🎉\nShe is so happy!\nAmazing product from realme\n\na. Awesome built quality\nb. Best Battery 🔋 little bit heavy but, it's fine to handle afterall it has 6000 mh battery 🔋\nc. Camera is good 🤳 front and back both. It will be better maybe after some updates.\nd. Display is also good\n\nThanks again!",
#  'Very nice mobile and battry is very extra powar and camera is nice this price range\nAnd delivery boy is very honest ..... Delivery boy rating is 5/5',
#  'Camera 4/5 if u able to set it properly\nBattery 5/5 very Good with great charging speed.\nDisplay 4/5 its not full hd but HD + with very good brightness and contrast\nPerformance is too good 5/5\n\nValue for Money\nSelfie and back camera capture are given below in low light photography in night time....\nTotal 4.5 out of 5 in my vision\nHope for best',
#  'Positive sides :\n1. Battery is very very powerful. Certainly exceeds your expectations.\n2. performance wise this phone is a very good purchase . smoothly functioning ..no lag..no heating issue.\n3. Day light pic quality is above average. Selfie camera good.\n4. There is dedicated slot for memory card apart from slots for 2 sim cards.\n\nNegative sides :\n1. Both rear and front camera in low light disappointing.\n2. Display could have been Full HD+ instead of HD+. Realme has disappointed its custome...',
#  'Excellent!!\nVery good mobile. I ordered it to my friend and he is very happy with it. Camera quality is good and battery backup is superb. Oxygen blue colour looks very attractive and rich. Highly recommended guys. Go for it.....',
#  'Best phone of this best valuable price..\nI think front camera is not enough in this price...\nBack camera very very good... My rating is __-\n\nCamera-:front-5,back-9,,\nBattery--:10\nPerformance-:8\nStorage-:8\nColour-:9\nProcessor g85-::::8\nVALUE of MONEY-;10',
#  'Best phone superb design and colour and performance is so good . Value for money i like it.',
#  "I bought it as a secondary device but was surprised by the camera quality at daylight (low light pics though are bit disappointing)\nBattery backup is quite good with 2 days of back up with normal usage.\nDisplay is also good for the price which one is paying.\nNo lags whatsoever though I haven't tried any high graphics games on this one.\nFinger print sensor too is very responsive but is slightly misplaced on the back panel(should have been at the centre).\nOver all a good budget phone(a complete...",
#  'It is a decent budgeted smart phone and main pros are Durable battery , big display good performance and good design with gaming processor from Helio G85. And Android 11\n\nThe corns are bit heavy and need lots of time to charge and heat bit while charging the phone.',
#  'Display could have FHD....camera is ok.\nRest are ok in this price. I assure you you will not be excited very okies phone. According to you must go another Better options in this price range.',
#  "Thanks again Flipkart team the wonderful delivery on time. Kind delivery boy.\nThis product purchased for my Mom 😍 and she is very happy gifted to mom on her birthday 🎉\nShe is so happy!\nAmazing product from realme\n\na. Awesome built quality\nb. Best Battery 🔋 little bit heavy but, it's fine to handle afterall it has 6000 mh battery 🔋\nc. Camera is good 🤳 front and back both. It will be better maybe after some updates.\nd. Display is also good\n\nThanks again!",
#  'Very nice mobile and battry is very extra powar and camera is nice this price range\nAnd delivery boy is very honest ..... Delivery boy rating is 5/5',
#  'Camera 4/5 if u able to set it properly\nBattery 5/5 very Good with great charging speed.\nDisplay 4/5 its not full hd but HD + with very good brightness and contrast\nPerformance is too good 5/5\n\nValue for Money\nSelfie and back camera capture are given below in low light photography in night time....\nTotal 4.5 out of 5 in my vision\nHope for best',
#  'Positive sides :\n1. Battery is very very powerful. Certainly exceeds your expectations.\n2. performance wise this phone is a very good purchase . smoothly functioning ..no lag..no heating issue.\n3. Day light pic quality is above average. Selfie camera good.\n4. There is dedicated slot for memory card apart from slots for 2 sim cards.\n\nNegative sides :\n1. Both rear and front camera in low light disappointing.\n2. Display could have been Full HD+ instead of HD+. Realme has disappointed its custome...',
#  'Excellent!!\nVery good mobile. I ordered it to my friend and he is very happy with it. Camera quality is good and battery backup is superb. Oxygen blue colour looks very attractive and rich. Highly recommended guys. Go for it.....',
#  'Best phone of this best valuable price..\nI think front camera is not enough in this price...\nBack camera very very good... My rating is __-\n\nCamera-:front-5,back-9,,\nBattery--:10\nPerformance-:8\nStorage-:8\nColour-:9\nProcessor g85-::::8\nVALUE of MONEY-;10',
#  'Best phone superb design and colour and performance is so good . Value for money i like it.',
#  "I bought it as a secondary device but was surprised by the camera quality at daylight (low light pics though are bit disappointing)\nBattery backup is quite good with 2 days of back up with normal usage.\nDisplay is also good for the price which one is paying.\nNo lags whatsoever though I haven't tried any high graphics games on this one.\nFinger print sensor too is very responsive but is slightly misplaced on the back panel(should have been at the centre).\nOver all a good budget phone(a complete...",
#  'It is a decent budgeted smart phone and main pros are Durable battery , big display good performance and good design with gaming processor from Helio G85. And Android 11\n\nThe corns are bit heavy and need lots of time to charge and heat bit while charging the phone.',
#  'Display could have FHD....camera is ok.\nRest are ok in this price. I assure you you will not be excited very okies phone. According to you must go another Better options in this price range.',
#  "Thanks again Flipkart team the wonderful delivery on time. Kind delivery boy.\nThis product purchased for my Mom 😍 and she is very happy gifted to mom on her birthday 🎉\nShe is so happy!\nAmazing product from realme\n\na. Awesome built quality\nb. Best Battery 🔋 little bit heavy but, it's fine to handle afterall it has 6000 mh battery 🔋\nc. Camera is good 🤳 front and back both. It will be better maybe after some updates.\nd. Display is also good\n\nThanks again!",
#  'Very nice mobile and battry is very extra powar and camera is nice this price range\nAnd delivery boy is very honest ..... Delivery boy rating is 5/5',
#  'Camera 4/5 if u able to set it properly\nBattery 5/5 very Good with great charging speed.\nDisplay 4/5 its not full hd but HD + with very good brightness and contrast\nPerformance is too good 5/5\n\nValue for Money\nSelfie and back camera capture are given below in low light photography in night time....\nTotal 4.5 out of 5 in my vision\nHope for best',
#  'Positive sides :\n1. Battery is very very powerful. Certainly exceeds your expectations.\n2. performance wise this phone is a very good purchase . smoothly functioning ..no lag..no heating issue.\n3. Day light pic quality is above average. Selfie camera good.\n4. There is dedicated slot for memory card apart from slots for 2 sim cards.\n\nNegative sides :\n1. Both rear and front camera in low light disappointing.\n2. Display could have been Full HD+ instead of HD+. Realme has disappointed its custome...',
#  'Excellent!!\nVery good mobile. I ordered it to my friend and he is very happy with it. Camera quality is good and battery backup is superb. Oxygen blue colour looks very attractive and rich. Highly recommended guys. Go for it.....',
#  'Best phone of this best valuable price..\nI think front camera is not enough in this price...\nBack camera very very good... My rating is __-\n\nCamera-:front-5,back-9,,\nBattery--:10\nPerformance-:8\nStorage-:8\nColour-:9\nProcessor g85-::::8\nVALUE of MONEY-;10',
#  'Best phone superb design and colour and performance is so good . Value for money i like it.',
#  "I bought it as a secondary device but was surprised by the camera quality at daylight (low light pics though are bit disappointing)\nBattery backup is quite good with 2 days of back up with normal usage.\nDisplay is also good for the price which one is paying.\nNo lags whatsoever though I haven't tried any high graphics games on this one.\nFinger print sensor too is very responsive but is slightly misplaced on the back panel(should have been at the centre).\nOver all a good budget phone(a complete...",
#  'It is a decent budgeted smart phone and main pros are Durable battery , big display good performance and good design with gaming processor from Helio G85. And Android 11\n\nThe corns are bit heavy and need lots of time to charge and heat bit while charging the phone.',
#  'Display could have FHD....camera is ok.\nRest are ok in this price. I assure you you will not be excited very okies phone. According to you must go another Better options in this price range.',
#  "Thanks again Flipkart team the wonderful delivery on time. Kind delivery boy.\nThis product purchased for my Mom 😍 and she is very happy gifted to mom on her birthday 🎉\nShe is so happy!\nAmazing product from realme\n\na. Awesome built quality\nb. Best Battery 🔋 little bit heavy but, it's fine to handle afterall it has 6000 mh battery 🔋\nc. Camera is good 🤳 front and back both. It will be better maybe after some updates.\nd. Display is also good\n\nThanks again!",
#  'Very nice mobile and battry is very extra powar and camera is nice this price range\nAnd delivery boy is very honest ..... Delivery boy rating is 5/5',
#  'Camera 4/5 if u able to set it properly\nBattery 5/5 very Good with great charging speed.\nDisplay 4/5 its not full hd but HD + with very good brightness and contrast\nPerformance is too good 5/5\n\nValue for Money\nSelfie and back camera capture are given below in low light photography in night time....\nTotal 4.5 out of 5 in my vision\nHope for best',
#  'Positive sides :\n1. Battery is very very powerful. Certainly exceeds your expectations.\n2. performance wise this phone is a very good purchase . smoothly functioning ..no lag..no heating issue.\n3. Day light pic quality is above average. Selfie camera good.\n4. There is dedicated slot for memory card apart from slots for 2 sim cards.\n\nNegative sides :\n1. Both rear and front camera in low light disappointing.\n2. Display could have been Full HD+ instead of HD+. Realme has disappointed its custome...',
#  'Excellent!!\nVery good mobile. I ordered it to my friend and he is very happy with it. Camera quality is good and battery backup is superb. Oxygen blue colour looks very attractive and rich. Highly recommended guys. Go for it.....',
#  'Best phone of this best valuable price..\nI think front camera is not enough in this price...\nBack camera very very good... My rating is __-\n\nCamera-:front-5,back-9,,\nBattery--:10\nPerformance-:8\nStorage-:8\nColour-:9\nProcessor g85-::::8\nVALUE of MONEY-;10',
#  'Best phone superb design and colour and performance is so good . Value for money i like it.',
#  "I bought it as a secondary device but was surprised by the camera quality at daylight (low light pics though are bit disappointing)\nBattery backup is quite good with 2 days of back up with normal usage.\nDisplay is also good for the price which one is paying.\nNo lags whatsoever though I haven't tried any high graphics games on this one.\nFinger print sensor too is very responsive but is slightly misplaced on the back panel(should have been at the centre).\nOver all a good budget phone(a complete...",
#  'It is a decent budgeted smart phone and main pros are Durable battery , big display good performance and good design with gaming processor from Helio G85. And Android 11\n\nThe corns are bit heavy and need lots of time to charge and heat bit while charging the phone.',
#  'Display could have FHD....camera is ok.\nRest are ok in this price. I assure you you will not be excited very okies phone. According to you must go another Better options in this price range.',
#  "First of all thanks to flipkart for excellent service. otherwise realme narzo 50 A is realy worst one in realme series, camera quality is so poor, it's not like 50mp camera it's like 2mp camera clarity is very dull n blur, don't buy if you want good camera phone",
#  'overall good product, mobile colour is good i liked it, camera back is good front is perfect, online buying is good beneficial for me.I recommend to all that buy online fon its better , always available in color and design. Backup also nice, i ordered and received before time same product nothing damage so i am happy for this. Thanks flipkart',
#  "This mobile has good features but battery doesn't seems to be an that much good performance though having 6000 Mah others features are great and display is awesome gaming performance is also good as well so overall nice phone and only big draw back Narzo should start giving silicon case which is not provided in the box.\n\nBasic need to protect the mobile.",
#  'I GOT THIS PHONE WITH SUPERB EXCHANGE DEAL\n\nCamera is not good upto 50mp\nBattery 🔋 is very good 👍\nDisplay is HD only not sAmoled\nSpeakers sound good\nRuns very smooth no lagging 👌.\nOverall its good budget smartphone.',
#  'I gift this to my mom. The joy in her eyes tells everything. Fantabulous phone. Thanks Realme and FlipKart for bringing this wonderful phone. Packaging was superb. Easy tracking and above all... Super quick delivery. Overall 5 star from my side. Thanks!',
#  "I have used this phone continuously last 7 days from delivery\nOver all ok\nBut delivery is soo late am disappointed it's take two weeks more time\nBattery performance is. Awesome\nBut charging time is more than 2 and half hours to full slightly disappointed\nBack camera 50 mp is awesome night scape photos is good\nSelfie camera performance is average\nIt has G85 processor is best performance\nOver all phone is worth for money go for it",
#  'What a mobile amazing battery back up also. Loved to purchase from flipkart. Delivery boy is also good behaviour. Best exchange prize.i got from flipkart',
#  'Very nice phone and value for mobile..\nCamera good, battery backup is very good\nDisplay nice, and performance is well so overall\nVery good mobile.',
#  'Mobile is good battery 6000ma super camera guality Vera level performance is good phone oxygen Blue closers super',
#  'Nice phone but if you want a good display and fast charging then go for realme narzo 30.',
#  "First of all thanks to flipkart for excellent service. otherwise realme narzo 50 A is realy worst one in realme series, camera quality is so poor, it's not like 50mp camera it's like 2mp camera clarity is very dull n blur, don't buy if you want good camera phone",
#  'overall good product, mobile colour is good i liked it, camera back is good front is perfect, online buying is good beneficial for me.I recommend to all that buy online fon its better , always available in color and design. Backup also nice, i ordered and received before time same product nothing damage so i am happy for this. Thanks flipkart',
#  "This mobile has good features but battery doesn't seems to be an that much good performance though having 6000 Mah others features are great and display is awesome gaming performance is also good as well so overall nice phone and only big draw back Narzo should start giving silicon case which is not provided in the box.\n\nBasic need to protect the mobile.",
#  'I GOT THIS PHONE WITH SUPERB EXCHANGE DEAL\n\nCamera is not good upto 50mp\nBattery 🔋 is very good 👍\nDisplay is HD only not sAmoled\nSpeakers sound good\nRuns very smooth no lagging 👌.\nOverall its good budget smartphone.',
#  'I gift this to my mom. The joy in her eyes tells everything. Fantabulous phone. Thanks Realme and FlipKart for bringing this wonderful phone. Packaging was superb. Easy tracking and above all... Super quick delivery. Overall 5 star from my side. Thanks!',
#  "I have used this phone continuously last 7 days from delivery\nOver all ok\nBut delivery is soo late am disappointed it's take two weeks more time\nBattery performance is. Awesome\nBut charging time is more than 2 and half hours to full slightly disappointed\nBack camera 50 mp is awesome night scape photos is good\nSelfie camera performance is average\nIt has G85 processor is best performance\nOver all phone is worth for money go for it",
#  'What a mobile amazing battery back up also. Loved to purchase from flipkart. Delivery boy is also good behaviour. Best exchange prize.i got from flipkart',
#  'Very nice phone and value for mobile..\nCamera good, battery backup is very good\nDisplay nice, and performance is well so overall\nVery good mobile.',
#  'Mobile is good battery 6000ma super camera guality Vera level performance is good phone oxygen Blue closers super',
#  'Nice phone but if you want a good display and fast charging then go for realme narzo 30.',
#  'Camera both front and back is Above Average,But Battery 🔋 Backup is Outstanding performance...if you are battery lover and best low budget mobile for value of our money💰Then no doubts to purchase it... quickly as soon as Possible...thank you Realme and thank you Flipkart,(Delivery boy)',
#  "Thanks again Flipkart team the wonderful delivery on time. Kind delivery boy.\n\nThis product purchased for my Mom and she is very happy gifted to mom on her birthday\n\nShe is so happy!\n\nAmazing product from realme\n\na. Awesome built quality\n\nb. Best Battery little bit heavy but, it's fine to handle afterall it has 6000 mh battery\n\nc. Camera is good front and back both. It will be better maybe after some updates.\n\nd. Display is also good",
#  'Very nice product with bright display and also smooth and great performance',
#  'Its good to have 6000mah battery but 18W charger is not good enough for 6000mah battery , it takes so long time to full charge the battery.',
#  'Nice mobile work is fast battery backup with super and slim mobile',
#  'Price wise perfect 👌.. Its claiming fast charging but its not.. Camera is good but not as expected.. Nyc performance.',
#  'Very good mobile in low price..👌👌👌👌👌\ngood camera...\nVery good battery backup...\nVery good display and very good performance....\nVery good mobile for gaming 😃😃',
#  'Realme nazro50a is good mobile phone and amount is good for Mobile .and 4gb ram and 128 gb is good phone in your range .best thank you...😃',
#  'Awesome android mobile in this price. Unbeatable price and features of mobile. Camera is great . Battery backup is very strong compare with other mobile.',
#  'Camera quality is good , battery 🔋 backup is good, screen touching power is smooth , nice product at this price finally this product is not bad and thanks Flipkart for this adorable phone',
#  "Expedited the display to be good. But the display is not up to the expectations rather than this mobile in this cost vivo will provide good quality of display.. . Camera is average, battery performance will be obviously good. Performance is okay. If you wish to pay games and watch movies or more videos this is not the good option. But it's value for money",
#  "It is a redesigned narzo 20 with following differences.\n\nNegative points-\n\nThey have removed gyroscope so you won't have functions like raise to wake screen and lift to pick up calls.You also won't get an ultra wide lens.\n\nBuild quality is slightly poorer than Narzo 20.\n\nPositive Points-\n\nOn the plus side it has a much brighter screen (500 plus units compared to Narzo 20) a slightly better main camera as it has 50 MP main lens with a dedicated depth senor for potrait mode\n\nIt also comes wit...",
#  "I love this phone , awesome battery life , awesome refresh rate ,all things is good , but I don't like back portion",
#  'Very nice phone ... U can buy it ... Camera quality is also good ❤️❤️',
#  'Excellent mobile in this price, camera is super',
#  'Awesome mobile. Just too good.',
#  'Good phone 📱',
#  'Very nice',
#  'Phone performance is quite good\nAll over in budget phone is totally paisa vasool',
#  'Amazing mobile.Thanks flipkart.',
#  "Expedited the display to be good. But the display is not up to the expectations rather than this mobile in this cost vivo will provide good quality of display.. . Camera is average, battery performance will be obviously good. Performance is okay. If you wish to pay games and watch movies or more videos this is not the good option. But it's value for money",
#  "It is a redesigned narzo 20 with following differences.\n\nNegative points-\n\nThey have removed gyroscope so you won't have functions like raise to wake screen and lift to pick up calls.You also won't get an ultra wide lens.\n\nBuild quality is slightly poorer than Narzo 20.\n\nPositive Points-\n\nOn the plus side it has a much brighter screen (500 plus units compared to Narzo 20) a slightly better main camera as it has 50 MP main lens with a dedicated depth senor for potrait mode\n\nIt also comes wit...",
#  "I love this phone , awesome battery life , awesome refresh rate ,all things is good , but I don't like back portion",
#  'Very nice phone ... U can buy it ... Camera quality is also good ❤️❤️',
#  'Excellent mobile in this price, camera is super',
#  'Awesome mobile. Just too good.',
#  'Good phone 📱',
#  'Very nice',
#  'Phone performance is quite good\nAll over in budget phone is totally paisa vasool',
#  'Amazing mobile.Thanks flipkart.',
#  'I love this phone',
#  'Lovely',
#  'Nice phone and smart gaming 👍👍☺️',
#  'Nice phone superbb quality camera.. good deal from flipkart',
#  'Camera is good',
#  'good',
#  "It's a very nice mobile you can never get this device in this price battery performance good but heat when you charge your mobile",
#  'best phone for students',
#  'Overall good performance 👍.\nCamera is ok.\nBattery backup is super.\nThank you flipkart and realme😊.',
#  'mind blowing i get it in special price☺️☺️\nsuper performance\ncamera preety good..\nbattery super\nquick charging\nbest buy😍',
#  'Nice phone 📱',
#  'Osm Product',
#  'Nice mobile good',
#  'Back camera and battery is very good',
#  'Nice product',
#  'Very Good quality',
#  'Thank you flipkart...\nProduct is Good...👍',
#  'Mobile is best battery backup but charging is slow .3hour time taken in full charge',
#  'Amazing camra',
#  'Super 👌 good mobile',
#  'Nice 👍 Smartphone good',
#  'Awesome',
#  'Mind-blowing phone',
#  'Camera is good.and batter backup is Awesome',
#  'Its camera quality and specifications are too good .....and battery is too long backup...',
#  'Average phone\nAcutely 9000 range phone',
#  ":- BATTERY BACKUP JUST OSM BUT CHARGING NOT FAST\nCAMERA IS USABLE NOT BAD\nBIG SCREEN\nSELFIE IS DECENT\nPROCESSOR IS DECENT\nALL ABOUT GOOD OPTION IN 10K\nNO LAG ISSUE AND HEAT ISSUE\n\nBEST FOR PARENT'S USE ❤",
#  'EXCELLENT PHONE FOR STUDENTS but NO GYROSENSOR',
#  'In this price sigment it should has Full HD+ display but it is only HD+ and processor g85 . Overall okey. Not too good.',
#  'Lot of Thanks for Flipkart team resolve any problem within a.minut .A grateful experience with customer cear .',
#  'Nice 👍 Smartphone good',
#  'Awesome',
#  'Mind-blowing phone',
#  'Camera is good.and batter backup is Awesome',
#  'Its camera quality and specifications are too good .....and battery is too long backup...',
#  'Average phone\nAcutely 9000 range phone',
#  ":- BATTERY BACKUP JUST OSM BUT CHARGING NOT FAST\nCAMERA IS USABLE NOT BAD\nBIG SCREEN\nSELFIE IS DECENT\nPROCESSOR IS DECENT\nALL ABOUT GOOD OPTION IN 10K\nNO LAG ISSUE AND HEAT ISSUE\n\nBEST FOR PARENT'S USE ❤",
#  'EXCELLENT PHONE FOR STUDENTS but NO GYROSENSOR',
#  'In this price sigment it should has Full HD+ display but it is only HD+ and processor g85 . Overall okey. Not too good.',
#  'Lot of Thanks for Flipkart team resolve any problem within a.minut .A grateful experience with customer cear .',
#  'Good but portrait mode is low',
#  'Narendra Sethy\nVery nice 👍 product',
#  'Literally, camera sukcs!!!!\nRealme accidentally added an extra 0 in front of 5. Making it 50MP instead of 5MP. Front camera also not good. I am using realme phones since laat 4 years , cameras are always their major buying point, but narzo 50a has it as a greatest drawback.\nRest all things are as per specification shown.\nOverall good if u can neglect camera .',
#  'So nice',
#  'ValuE\nFoR\n\n\nMoney 💸',
#  'Overall the performance of this mobile good in below 10k range.',
#  'good',
#  'value for money..\nGreat',
#  'Nice 😘😘😘',
#  'It was totally a mixed experience in terms of camera in light it produces fantastic photos and in low light it produce the photo like its some cheap kind of 2MP camera from nokia phones.\nPerformance is good according to price.',
#  'Good......',
#  'The mobile is a good purchase at this price,battery is high powered,last long,picture sharp,sound quality is good, 50mp camera is superb.',
#  'I bought this phone for my maternal uncle and he absolutely loved it. Good camera set up, great battery and display',
#  'Good product but display only should be full hd+',
#  'Suprb',
#  'This product is wonderful but the camera is not bad nor good',
#  "Good phone I'm SO happy🥰🥰🥰",
#  'Display Is Average .. Battery Back up Good . Camera need improvement .. average ... value for money in this price segment',
#  "Fingerprint sensor are slightly upward from its normal position so when you try to touch the sensor you'll feel like you are touching camera (but you're not touching camera) except this the phone is good and 128 GB storage is a plus factor in this budget!",
#  'Best budget phone.\nOnly front camera not too good.',
#  'Good......',
#  'The mobile is a good purchase at this price,battery is high powered,last long,picture sharp,sound quality is good, 50mp camera is superb.',
#  'I bought this phone for my maternal uncle and he absolutely loved it. Good camera set up, great battery and display',
#  'Good product but display only should be full hd+',
#  'Suprb',
#  'This product is wonderful but the camera is not bad nor good',
#  "Good phone I'm SO happy🥰🥰🥰",
#  'Display Is Average .. Battery Back up Good . Camera need improvement .. average ... value for money in this price segment',
#  "Fingerprint sensor are slightly upward from its normal position so when you try to touch the sensor you'll feel like you are touching camera (but you're not touching camera) except this the phone is good and 128 GB storage is a plus factor in this budget!",
#  'Best budget phone.\nOnly front camera not too good.',
#  'Satisfied by the price',
#  'Osm and looking attractive...',
#  'Selfie camera is very bad',
#  "Utterly disappointed...I was excited by seeing the battery is 6000 mah and camera 50 mp but actually it's below average performance and it takes very long time to get charged fully and if we Google any website it's not opening, really it's nightmare for me, I feel like the company is cheating by giving wrong features",
#  'Very nice camera in this range and battery backup is also too good👍 ☺☺😍😍😍😍😍',
#  'Nice 👍',
#  'Display is poor\nFunction are not that smoother\nI would like to buy Motorola Phones in this range comparative to realme phones\nTouch is not that faster as shown\nFor finger sensor you have to find the area for touch\nOver all this is not worth of 12k phone, it must be of around 8k-9k.',
#  'Nice',
#  'Best Mobile\n\n\nSelfie & Back Camera\n\n\nCharger Type c',
#  'This phone camera is not a good quality 😔😔',
#  'It was totally a mixed experience in terms of camera in light it produces fantastic photos and in low light it produce the photo like its some cheap kind of 2MP camera from nokia phones.\nPerformance is good according to price.',
#  'So nice and smooth camera with big storage and battery are long last',
#  'Sonu and camera clearty is so beautiful and display is very very smooth',
#  'I am so thankful to delivery boy for helping me during delivery and faster delivery. He has knowledge.',
#  'Nice Product ☺️👍😊',
#  "I'm really disappointed with camera performance it's not 50 megapixel camera it's like old VGI or 1.3 camera worst product..",
#  "Worst Mobile\nI am taken worst photos in this camera\nI am not see within half hour this mobile because mind is distributed and eyes are too disturbed. Battery performance is good.\nBattery charging is too much time\nI am requesting to other members please don't by this mobile",
#  'Osm and looking attractive...',
#  'Good mobile in lower price, Camera MP very poor quality as per given camera specification',
#  'Selfie camera is very bad',
#  'It was totally a mixed experience in terms of camera in light it produces fantastic photos and in low light it produce the photo like its some cheap kind of 2MP camera from nokia phones.\nPerformance is good according to price.',
#  'So nice and smooth camera with big storage and battery are long last',
#  'Sonu and camera clearty is so beautiful and display is very very smooth',
#  'I am so thankful to delivery boy for helping me during delivery and faster delivery. He has knowledge.',
#  'Nice Product ☺️👍😊',
#  "I'm really disappointed with camera performance it's not 50 megapixel camera it's like old VGI or 1.3 camera worst product..",
#  "Worst Mobile\nI am taken worst photos in this camera\nI am not see within half hour this mobile because mind is distributed and eyes are too disturbed. Battery performance is good.\nBattery charging is too much time\nI am requesting to other members please don't by this mobile",
#  'Osm and looking attractive...',
#  'Good mobile in lower price, Camera MP very poor quality as per given camera specification',
#  'Selfie camera is very bad',
#  'Very nice mobile',
#  'Nice phone awesome camera mind blowing battery back up chip price thanks to filpkart',
#  'Nice 👍👍👍👍👍👍 i.m happy',
#  'Display Is Average .. Battery Back up Good . Camera need improvement .. average ... value for money in this price segment',
#  "Very low buffering speed\nPoor performance\nLow speaker volume\nDon't buy this phone.\nI regret within minutes after buying this phone.",
#  'Camera quality is very poor as per description show 48 megapixel but photo click as a 5 MP camera',
#  'Awesome phone..but slow charging',
#  "Very nice / didn't thought I would get this get this in good state but got it",
#  'Good mobile in this price range.',
#  'Value for money ok',
#  'Very nice mobile',
#  'Nice phone awesome camera mind blowing battery back up chip price thanks to filpkart',
#  'Nice 👍👍👍👍👍👍 i.m happy',
#  'Display Is Average .. Battery Back up Good . Camera need improvement .. average ... value for money in this price segment',
#  "Very low buffering speed\nPoor performance\nLow speaker volume\nDon't buy this phone.\nI regret within minutes after buying this phone.",
#  'Camera quality is very poor as per description show 48 megapixel but photo click as a 5 MP camera',
#  'Awesome phone..but slow charging',
#  "Very nice / didn't thought I would get this get this in good state but got it",
#  'Good mobile in this price range.',
#  'Value for money ok',
#  'All the reviews you have see on flipkart is fake only made by offering some cashback or coupon discount.\nI am very disappointed with front and back camera both in low light. This is also not upto the mark. Battery backup is good. Overall performance is more than good.',
#  'Nice phone 🐱',
#  'Nice 😘😘😘',
#  'Osm I gifted my bhai n he really like it....n camera quality is lovely',
#  "Good phone for the budget.\nBattery backup is good.\nDisplay according to the price it's fine.\nOverall a very good package",
#  'Worth',
#  'Nice product in this range',
#  'Best smartphone Realme Narzo 50A.',
#  'I bought this phone for my maternal uncle and he absolutely loved it. Good camera set up, great battery and display',
#  'Value for money,, outstanding performance,, nice product,👌👌👌 mind blowing camera quality,,,',
#  'Best Performance',
#  '1.Display quality is very bad,\n2. Camera is not good,\n3. Battery is good,\n4. Performance is avarage\n5. Back side look is bad,',
#  'Display is poor\nFunction are not that smoother\nI would like to buy Motorola Phones in this range comparative to realme phones\nTouch is not that faster as shown\nFor finger sensor you have to find the area for touch\nOver all this is not worth of 12k phone, it must be of around 8k-9k.',
#  'Phone performance is good. Battery charge takes very long time. Battery Drain is better Because 6000mah.other wise good.',
#  'Good',
#  'It’s a great phone and as per performance it’s awesome battery life also very good',
#  'Good product and value for money',
#  'Good dailyvary at the time and the dailyvary man is helpful...I am Happy and satisfy🙂',
#  'OSM SMARTPHONE AND LIKE TO KEEP IT IN EMAIL',
#  "Don't waste ur money",
#  'Best Performance',
#  '1.Display quality is very bad,\n2. Camera is not good,\n3. Battery is good,\n4. Performance is avarage\n5. Back side look is bad,',
#  'Display is poor\nFunction are not that smoother\nI would like to buy Motorola Phones in this range comparative to realme phones\nTouch is not that faster as shown\nFor finger sensor you have to find the area for touch\nOver all this is not worth of 12k phone, it must be of around 8k-9k.',
#  'Phone performance is good. Battery charge takes very long time. Battery Drain is better Because 6000mah.other wise good.',
#  'Good',
#  'It’s a great phone and as per performance it’s awesome battery life also very good',
#  'Good product and value for money',
#  'Good dailyvary at the time and the dailyvary man is helpful...I am Happy and satisfy🙂',
#  'OSM SMARTPHONE AND LIKE TO KEEP IT IN EMAIL',
#  "Don't waste ur money",
#  "Phone is good but Don't buy the same through flipkart. They are just claiming false information provided by them on their platform. Please don't buy through flipkart else you will be cheated and will regret the same later",
#  'Nice product😍',
#  'Good',
#  'Camra quality is not good',
#  'Good smartphone\nGood smartphone good performance',
#  'I am fully satisfied with the product...',
#  'Good Product',
#  'Camera and battery backup unbelievable.and all over performance is to good,thanks flipkart and realme.',
#  'Nice Product..',
#  'Good.',
#  'A very nice product .. fully matched with my expectations...value for money...nice performance...go for it??',
#  'Good budget phone and reliable.',
#  'Excellent But\n3 hour charger',
#  'Awesome 👌',
#  'Nice products',
#  'I am really very disappointed, I have exchanged my redmi note 7 pro, it was really a suburb mobile. Realme narzi 50a is very disappointing phone, No good camera , no good battery backup, nothing. First time bought Realme phone, I will not suggest anyone in future.',
#  'Poor',
#  'BEST mobile under 11000 go for it',
#  'Not Expected For Realme, This Mobile Slow Work.. Not Perfect.. Camera Bad Quality.. Some Time Hang out ..Better Going Other Mobile Or Other Brand.',
#  'Bad mobile.',
#  'A very nice product .. fully matched with my expectations...value for money...nice performance...go for it??',
#  'Good budget phone and reliable.',
#  'Excellent But\n3 hour charger',
#  'Awesome 👌',
#  'Nice products',
#  'I am really very disappointed, I have exchanged my redmi note 7 pro, it was really a suburb mobile. Realme narzi 50a is very disappointing phone, No good camera , no good battery backup, nothing. First time bought Realme phone, I will not suggest anyone in future.',
#  'Poor',
#  'BEST mobile under 11000 go for it',
#  'Not Expected For Realme, This Mobile Slow Work.. Not Perfect.. Camera Bad Quality.. Some Time Hang out ..Better Going Other Mobile Or Other Brand.',
#  'Bad mobile.',
#  'Nice Phone',
#  'I purchased this Phone 2 days ago.Apart from all specifications,it was written that ,Fast charging was there.but it was slower than normal.It took more than 5 hours for charging,though not fully charged. Please give clarification and solution on this.',
#  'Volume very slow. And mobile hung issue. Camera clarity is not good. So I need replacement or refund',
#  'Best and no comments for bad reviews. You can go with this product. Super 👌 👍 😍',
#  'Good but portrait mode is low',
#  'Back camara nice but front camara bad',
#  'Good products\nPowerful battery\nNice camera\nPowerful gaming processor\nSamrt Finishing',
#  'Very bad product camera is very poor',
#  'Excellent product ✌️✌️',
#  'Bad',
#  'Nice Phone',
#  'I purchased this Phone 2 days ago.Apart from all specifications,it was written that ,Fast charging was there.but it was slower than normal.It took more than 5 hours for charging,though not fully charged. Please give clarification and solution on this.',
#  'Volume very slow. And mobile hung issue. Camera clarity is not good. So I need replacement or refund',
#  'Best and no comments for bad reviews. You can go with this product. Super 👌 👍 😍',
#  'Good but portrait mode is low',
#  'Back camara nice but front camara bad',
#  'Good products\nPowerful battery\nNice camera\nPowerful gaming processor\nSamrt Finishing',
#  'Very bad product camera is very poor',
#  'Excellent product ✌️✌️',
#  'Bad',
#  'Overall Good phone\nBattery backup- excellent\nCamera - average\nDisplay- Good',
#  '1.Camera quality is average\n\n2.battery life is awesome\n\n3. Green colour is looking fabulous\n\nTHANKS TO FLIPKART THANKS FOR KOTAK DISCOUNT 🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏\n\nI AM PURCHASING 11000 RUPEES',
#  'Poor camera result',
#  'Awesome',
#  'This is really a huge phone.Camera and speakers are decent.',
#  'Beyond expectations',
#  'Nice',
#  'Camera not good .battery back up good.disply not good.',
#  "It's a good phone overall...only problem with the UI which seems old, but in turn saves battery consumption.. camera is good at this price, processor/performance is average. Satisfied overall with the product",
#  'Mobile camera amazing\nBettery is so powerful\nNice movie value for money 💰',
#  'OSM Mobile',
#  'Bettry power so good very good\nDisplay v good\nBack camera good but selfe camera not good',
#  'Good',
#  'nice product',
#  "Display , Performance , Look very good\nBattery capacity not like 6000mah it's 4000mah\n& Drain very fast in normal internet usage.",
#  'Okeish.. nt OSM',
#  'Nice one',
#  'Good',
#  'Awesome mobile',
#  'Nice',
#  'Average',
#  'Narzo series is the best',
#  "Mobile camera is very low category, don't purchase it.",
#  'Realme best budget phone excellent performance l loved realme brand.',
#  'Best performance',
#  'Nice',
#  'Osm picture quality 😍😍thanks Flipkart ❤️❤️',
#  'Supper se upper',
#  'Camera quality is not at all like 50mp.',
#  "Worst camera quality......very bad quality photos.... please don't buy the product",
#  'Average',
#  'Narzo series is the best',
#  "Mobile camera is very low category, don't purchase it.",
#  'Realme best budget phone excellent performance l loved realme brand.',
#  'Best performance',
#  'Nice',
#  'Osm picture quality 😍😍thanks Flipkart ❤️❤️',
#  'Supper se upper',
#  'Camera quality is not at all like 50mp.',
#  "Worst camera quality......very bad quality photos.... please don't buy the product",
#  'Good',
#  'Do not buy this product camera quality is very bad like 8MP. Front cam portrait mode wrost like ears are not visible.',
#  'Good',
#  'Everything is ok except no 4K video recording option in 50 MP main Camera',
#  'All good but disappointed with the camara quality. In this range of mobile i think need to improve your camara quality.',
#  'I loved the product, its working like makhan',
#  'All good in the phone and full value of money, but issue is on the piece of delivery which is very poor, Got if after gifting to someone else on occasion.',
#  'Sound problem for calling time',
#  'very bad',
#  'Hanging problem.camra not clear.over all 3 number in 10',
#  'Bad product.did not replace this product',
#  'Nice',
#  'Super power phone...\nBattery 🔋 super..\nCamera 📸 50mp👌',
#  'Good',
#  'Super really love this mobile',
#  "It's okay",
#  'Always freezing',
#  'Best',
#  'This phone was good 🤗🔥',
#  'This prices are very good mobile phone',
#  'Bad product.did not replace this product',
#  'Nice',
#  'Super power phone...\nBattery 🔋 super..\nCamera 📸 50mp👌',
#  'Good',
#  'Super really love this mobile',
#  "It's okay",
#  'Always freezing',
#  'Best',
#  'This phone was good 🤗🔥',
#  'This prices are very good mobile phone',
#  'Front camera changes the image quality after clicking',
#  'Value for money',
#  'Good service 👍 good quality lowest budget phone',
#  'Good',
#  'Not good camera📷',
#  'Very good',
#  'Best',
#  'Nice phon',
#  'Good',
#  'Nice smartphone....',
#  'Front camera changes the image quality after clicking',
#  'Value for money',
#  'Good service 👍 good quality lowest budget phone',
#  'Good',
#  'Not good camera📷',
#  'Very good',
#  'Best',
#  'Nice phon',
#  'Good',
#  'Nice smartphone....',
#  'Thank you Flipkart',
#  'Nice phone',
#  'Excellent product',
#  "Phone's quality is very good\nBut one problem\nBack cover isn't given",
#  'I like it',
#  'Osm',
#  'Very nice mobile full paisa vsul product thanks Flipkart 🥰🥰🥰🥰🥰🥰',
#  'Very Good product best quality\nBig billion days offer 9899Rs\nGood camera 📸\nBattery backup super 👍\nNice look',
#  'Wt a phone super qty And good camara',
#  'Good Phone',
#  'Thank you Flipkart',
#  'Nice phone',
#  'Excellent product',
#  "Phone's quality is very good\nBut one problem\nBack cover isn't given",
#  'I like it',
#  'Osm',
#  'Very nice mobile full paisa vsul product thanks Flipkart 🥰🥰🥰🥰🥰🥰',
#  'Very Good product best quality\nBig billion days offer 9899Rs\nGood camera 📸\nBattery backup super 👍\nNice look',
#  'Wt a phone super qty And good camara',
#  'Good Phone',
#  'Better',
#  'Better',
#  'Spr mass pangu',
#  'Camera is very poor but battery and storage good',
#  'Camra quality poor and slow while working on data\nPoor performance',
#  'Amazing',
#  'Awesome phone',
#  'Very nice',
#  'Good',
#  'Good',
#  'Camera I Ok\nDisplay is Not so much Good\nProcessor is not so much Good\nBattery backup is Excellent\nDesign in Excellent\nValue for money below 10K.',
#  'Awesome Phone',
#  'Nice phone & lowest cost phone',
#  'Osam mobile nice price',
#  'Awesome Mobile. Call Recording needs to be updated so that all calls can get recorded.',
#  'Very good phone.',
#  'Average phone, taking too much time to charge. Camera is average.',
#  "The Camera is good as expected.\n6000mAh battery (You can use this for two days (normal usage) without charging 🥰) with 18W adapter charges from 0 to 100 in 2hr 10mins\nIt's been 10 days and there has been no issue related to anything\nAnd the phone comes with a screen protect film (no scratches 😁)\nOver-all best buy at this range",
#  'Nice battery.',
#  'Bivotao Sundor Jinish. Go for it. Battery lasts for 1 whole day of watching movies. Asombhob sundor',
#  'Camera I Ok\nDisplay is Not so much Good\nProcessor is not so much Good\nBattery backup is Excellent\nDesign in Excellent\nValue for money below 10K.',
#  'Awesome Phone',
#  'Nice phone & lowest cost phone',
#  'Osam mobile nice price',
#  'Awesome Mobile. Call Recording needs to be updated so that all calls can get recorded.',
#  'Very good phone.',
#  'Average phone, taking too much time to charge. Camera is average.',
#  "The Camera is good as expected.\n6000mAh battery (You can use this for two days (normal usage) without charging 🥰) with 18W adapter charges from 0 to 100 in 2hr 10mins\nIt's been 10 days and there has been no issue related to anything\nAnd the phone comes with a screen protect film (no scratches 😁)\nOver-all best buy at this range",
#  'Nice battery.',
#  'Bivotao Sundor Jinish. Go for it. Battery lasts for 1 whole day of watching movies. Asombhob sundor',
#  "I am using this phone since last few days ,the battery is so powerfull ,but at the time of buying this phone I saw its also supports 18 watt charging but after i put this phone on 18 watt charger the phone is not charging fastly ,it's taking 3 hr to charge fully ,it's really disappointing.",
#  'thanks',
#  'Value added for money',
#  "It's too Gud with Quality of the Product.",
#  'Good',
#  'Good Mobile',
#  'Good Mobile',
#  'The awesome phone is perfect for everything',
#  'Osm mobile',
#  'Under 10k value for money',
#  'Battery was awesome but camera not so good ... although this phone is value for money',
#  'Very nice design and sturdy phone',
#  'Not fully satisfied',
#  'Good quality',
#  'Best phone.',
#  "It's amazing 😍",
#  'Osm',
#  'Good phone but price are little high',
#  'Good',
#  'Amazing phoone for the budget...under 10k.. both battery backup and performance is good.',
#  'Superb\nThank you thank you thank you',
#  'Good at this price of point',
#  'Very Good Product',
#  'Nyc',
#  'Good',
#  'Good..',
#  'Good..',
#  'Good mobile... Besttt',
#  'Good. Awsome phone..poli saanm',
#  'Good mobile in this price Range',
#  'Awsome phone awsome service by flipkart thank you flipkart family',
#  'Average product',
#  'Nice one',
#  'A very nice camera and battery performance but the weight of the phone is nearly 250g',
#  'Nice product',
#  'Camera is awesome 😍',
#  'Good',
#  'The mobile is good',
#  'Fabulous product and nice service 👍',
#  'Looks good',
#  'Nice one',
#  'nice phone',
#  'Nice phone.',
#  'Good and nice mobile',
#  'Nice',
#  'Excellent',
#  'Very nice product as well as service provided by Flipkart...',
#  "Excellent mobile color, we like it. It's osm 🥰🥰😘👍❤️and the delivery boy's behave was so nice 👍👍",
#  'Good',
#  'Ok ok',
#  'Great specs',
#  'Value for money',
#  'Good 👍',
#  'Very Nice Budget mobile . Battery and Camera is the main receipe of this phone.',
#  'Superb',
#  'Nice phone',
#  'Excellent',
#  'Good',
#  'Good 👌',
#  'God phone',
#  'Not bad',
#  'Excellent mobile ..good battery backup.',
#  'Good..',
#  'Nice Mobile very smooth.',
#  'Good performance\nCould be lesser price than it has',
#  'Wonderful phone in 11k I really appreciate flipkart to giving offers thank you for delivery person also...',
#  'Value for money. Recommended to buy',
#  'Nice and good',
#  'Good one at this price but it could have some additional features.',
#  'I was deceived by specs..camera is very very poor, performance is laggy...screen glitches in transitions...not a single pro found in this mobile...it must cost around 8500 for its specs.very thick, not at all handy heavy weight...realme 8i is far better atleast in looks(I ordered both for my relatives)..no back case provided in the box.',
#  'I give my review after the usage of 1 year it was really a nice product',
#  'Good phone and best phone for narjo 20',
#  'Touch response is poor and camera quality also poor',
#  'Dispointed',
#  'Next level smartphone',
#  'Superb phone in this price range',
#  'Osm 😍😍😘',
#  'Awesome phone 📱 and best Kotak Mahindra Bank dabit card EMI service\nI really happy 😊',
#  'OSM',
#  'Very nice product\nFully satisfied realme narzo 50\nCamera quality is good',
#  'I give my review after the usage of 1 year it was really a nice product',
#  'Good phone and best phone for narjo 20',
#  'Touch response is poor and camera quality also poor',
#  'Dispointed',
#  'Next level smartphone',
#  'Superb phone in this price range',
#  'Osm 😍😍😘',
#  'Awesome phone 📱 and best Kotak Mahindra Bank dabit card EMI service\nI really happy 😊',
#  'OSM',
#  'Very nice product\nFully satisfied realme narzo 50\nCamera quality is good',
#  "Absolutely rubbish product, rear camera superb waste. Don't waste your money",
#  'Camera very bad\nSpoil money realme mobile very bad camera quality\nFlipkart selling low quality products',
#  'Best mobile realme Narzo 50A',
#  'Very good..😍😘 Camera and Nice battery backup 😍.,',
#  'Camera quality not gud front and rear',
#  'Camera and display bad quality',
#  'dont buy',
#  'Very good product',
#  'This mobile is very bad\nTotally waste of money',
#  'Average and a bit overpriced.\nBattery backup is excellent but charging time is more than 3 hours. Just skip and go for other to buy.',
#  'Nice mobaile',
#  'Nice',
#  'Very nice this product',
#  'Very good phone . Must buy.',
#  "This phone is amazing n worth it's price, it's a must buy product ,but\nNEVER GIVE YOUR PHONE FOR EXCHANGE,they fool customers!!!",
#  'Nise',
#  'Nice mobile',
#  'Best phone in this budget... smooth experience with long lasting battery...',
#  'Super camera',
#  'It is a good budget phone reg camera it is not 50mp it is work as 13 mp camera something it disappointed you much. Other than that a good phone to buy',
#  'good product below 10k above redmi 10 prime is better option on 11k or below',
#  'Batery backup is osme',
#  'Good mobile and value for money. HD+ display looks bit dull... FHD could have been better... Camera is above average and battery is good',
#  'Even with 18W charged it takes more than 3.5 hour to charge this phone, seems fast charger is dummy only.\nBack camera is good but front is less than average',
#  'Fantastic mind blowing mobile',
#  'Awasome phone in this range',
#  'Good products',
#  'Nice',
#  'Nice product on this unbelievable price',
#  'Nice mobile',
#  'good product below 10k above redmi 10 prime is better option on 11k or below',
#  'Batery backup is osme',
#  'Good mobile and value for money. HD+ display looks bit dull... FHD could have been better... Camera is above average and battery is good',
#  'Even with 18W charged it takes more than 3.5 hour to charge this phone, seems fast charger is dummy only.\nBack camera is good but front is less than average',
#  'Fantastic mind blowing mobile',
#  'Awasome phone in this range',
#  'Good products',
#  'Nice',
#  'Nice product on this unbelievable price',
#  'Nice mobile',
#  'Nice mobaile',
#  'Nice',
#  'Very nice this product',
#  'Very good phone . Must buy.',
#  "This phone is amazing n worth it's price, it's a must buy product ,but\nNEVER GIVE YOUR PHONE FOR EXCHANGE,they fool customers!!!",
#  'Nise',
#  'Nice mobile',
#  'Best phone in this budget... smooth experience with long lasting battery...',
#  'Super camera',
#  'It is a good budget phone reg camera it is not 50mp it is work as 13 mp camera something it disappointed you much. Other than that a good phone to buy',
#  'good product below 10k above redmi 10 prime is better option on 11k or below',
#  'Batery backup is osme',
#  'Good mobile and value for money. HD+ display looks bit dull... FHD could have been better... Camera is above average and battery is good',
#  'Even with 18W charged it takes more than 3.5 hour to charge this phone, seems fast charger is dummy only.\nBack camera is good but front is less than average',
#  'Fantastic mind blowing mobile',
#  'Awasome phone in this range',
#  'Good products',
#  'Nice',
#  'Nice product on this unbelievable price',
#  'Nice mobile']

# %%
url='https://www.flipkart.com/hp-pavilion-gaming-ryzen-5-hexa-core-4600h-8-gb-1-tb-hdd-windows-10-home-4-gb-graphics-nvidia-geforce-gtx-1650-15-ec1021ax-laptop/product-reviews/itm70c8fb9efbb8c?pid=COMFT8GXGSJZKAAE&lid=LSTCOMFT8GXGSJZKAAEFE91VM&marketplace=FLIPKART'
driver.get(url)

# %%
full_reviews1=[]
ratings1=[]

# %%
# fetching first pages reviews
for a in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
    full_reviews1.append(a.text)
for b in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
    ratings1.append(b.text)
time.sleep(1)
        #clciking on second page for reviews
driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
time.sleep(2)
        # running loop till the end of pages of all reviews
while True:
    time.sleep(2)
    for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        full_reviews1.append(i.text)
    for j in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        ratings1.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]/span").click()
        time.sleep(1)
    except:
        break

# %%
len(full_reviews1)
# Out:
# 310

# %%
len(ratings1)
# Out:
# 310

# %%
url='https://www.flipkart.com/samsung-80-cm-32-inch-hd-ready-led-smart-tv/product-reviews/itm6e40262f4572a?pid=TVSFQXFKMHUDYCJ3&lid=LSTTVSFQXFKMHUDYCJ3IOJXHJ&marketplace=FLIPKART'
driver.get(url)

# %%
full_reviews2=[]
ratings2=[]

# %%
# fetching first pages reviews
for a in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
    full_reviews2.append(a.text)
for b in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
    ratings2.append(b.text)
time.sleep(1)
        #clciking on second page for reviews
driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
time.sleep(2)
        # running loop till the end of pages of all reviews
while True:
    time.sleep(2)
    for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        full_reviews2.append(i.text)
    for j in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        ratings2.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]/span").click()
        time.sleep(1)
    except:
        break

# %%
len(ratings2)
# Out:
# 3945

# %%
len(full_reviews2)
# Out:
# 3945

# %%
full_reviews2
# Out:
# ['Very good',
#  'Good at this price',
#  'Absulately good product.value for money.',
#  'Overall a good gaming laptop for this price segment',
#  'This Laptop is beast in performance. Thanks Flipkart for the fast delivery.',
#  'Performance worst',
#  'Value for money',
#  "It's the best product I got at big billion sale got it for 50k the delivery was Expected for 3 days took 3 whole weeks for delivery.\nIt's a beast",
#  'Best laptop at this price range!!\nBut in my opinion if you have Little more money then go for ssd version.',
#  'Value for money',
#  'Very good',
#  'Good at this price',
#  'Absulately good product.value for money.',
#  'Overall a good gaming laptop for this price segment',
#  'This Laptop is beast in performance. Thanks Flipkart for the fast delivery.',
#  'Performance worst',
#  'Value for money',
#  "It's the best product I got at big billion sale got it for 50k the delivery was Expected for 3 days took 3 whole weeks for delivery.\nIt's a beast",
#  'Best laptop at this price range!!\nBut in my opinion if you have Little more money then go for ssd version.',
#  'Value for money',
#  'Very good',
#  'Good at this price',
#  'Absulately good product.value for money.',
#  'Overall a good gaming laptop for this price segment',
#  'This Laptop is beast in performance. Thanks Flipkart for the fast delivery.',
#  'Performance worst',
#  'Value for money',
#  "It's the best product I got at big billion sale got it for 50k the delivery was Expected for 3 days took 3 whole weeks for delivery.\nIt's a beast",
#  'Best laptop at this price range!!\nBut in my opinion if you have Little more money then go for ssd version.',
#  'Value for money']

# %%
url='https://www.flipkart.com/oneplus-y-series-100-cm-40-inch-full-hd-led-smart-android-tv/product-reviews/itmdcbd9784403b2?pid=TVSG25MMGB8NKFD8&lid=LSTTVSG25MMGB8NKFD8MWAMJF&marketplace=FLIPKART'
driver.get(url)

# %%
full_reviews3=[]
ratings3=[]

# %%
# fetching first pages reviews
for a in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
    full_reviews3.append(a.text)
for b in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
    ratings3.append(b.text)
time.sleep(1)
        #clciking on second page for reviews
driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
time.sleep(2)
        # running loop till the end of pages of all reviews
while True:
    time.sleep(2)
    for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        full_reviews3.append(i.text)
    for j in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        ratings3.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]/span").click()
        time.sleep(1)
    except:
        break

# %%
len(full_reviews3)
# Out:
# 4879

# %%
len(ratings3)
# Out:
# 4879

# %%
full_reviews_n=full_reviews+full_reviews1+full_reviews2+full_reviews3
len(full_reviews_n)
# Out:
# 11968

# %%
ratings_n=ratings+ratings1+ratings2+ratings3
len(ratings_n)
# Out:
# 11968

# %%
df = pd.DataFrame({})
df["full_reviews"] = full_reviews_n
df["ratings"] = ratings_n
df
# Out:
#                                             full_reviews ratings
# 0      First of all thanks to flipkart for excellent ...       2
# 1      overall good product, mobile colour is good i ...       5
# 2      This mobile has good features but battery does...       4
# 3      I GOT THIS PHONE WITH SUPERB EXCHANGE DEAL\n\n...       5
# 4      I gift this to my mom. The joy in her eyes tel...       5
# ...                                                  ...     ...
# 11963                                     budjet tv good       5
# 11964                                  Value for product       5
# 11965                                          Excellent       5
# 11966  Best among the market at this price range. Uni...       4
# 11967  It's simply great tv in its price segments\nLo...       5
#
# [11968 rows x 2 columns]

# %%
df.to_csv("review_data")

# %%
driver.close()

# %%
url='https://www.flipkart.com/oneplus-y-series-80-cm-32-inch-hd-ready-led-smart-android-tv/product-reviews/itme650a6bb8cee3?pid=TVSFVWD2ENXYGEJY&lid=LSTTVSFVWD2ENXYGEJY9U6ROG&marketplace=FLIPKART'
driver.get(url)

# %%
full_reviews=[]
ratings=[]

# %%
# fetching first pages reviews
for a in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
    full_reviews.append(a.text)
for b in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
    ratings.append(b.text)
time.sleep(1)
        #clciking on second page for reviews
driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
time.sleep(2)
        # running loop till the end of pages of all reviews
while True:
    time.sleep(2)
    for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        full_reviews.append(i.text)
    for j in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        ratings.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]/span").click()
        time.sleep(1)
    except:
        break

# %%
len(full_reviews)
# Out:
# 5975

# %%
len(ratings)
# Out:
# 5975

# %%
url='https://www.flipkart.com/realme-108-cm-43-inch-ultra-hd-4k-led-smart-android-tv-handsfree-voice-search-dolby-vision-atmos/product-reviews/itm961db6696ab0a?pid=TVSG2B4AKVHCUJ8P&lid=LSTTVSG2B4AKVHCUJ8PB7ZMW9&marketplace=FLIPKART'
driver.get(url)

# %%
full_reviews1=[]
ratings1=[]

# %%
# fetching first pages reviews
for a in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
    full_reviews1.append(a.text)
for b in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
    ratings1.append(b.text)
time.sleep(1)
        #clciking on second page for reviews
driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
time.sleep(2)
        # running loop till the end of pages of all reviews
while True:
    time.sleep(2)
    for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        full_reviews1.append(i.text)
    for j in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        ratings1.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]/span").click()
        time.sleep(1)
    except:
        break

# %%
len(full_reviews1)
# Out:
# 2220

# %%
len(ratings1)
# Out:
# 2220

# %%
full_reviews_m=full_reviews+full_reviews1
len(full_reviews_m)
# Out:
# 8195

# %%
ratings_m=ratings+ratings1
len(ratings_m)
# Out:
# 8195

# %%
df1 = pd.DataFrame({})
df1["full_reviews"] = full_reviews_m
df1["ratings"] = ratings_m
df1
# Out:
#                                            full_reviews ratings
# 0     It is superior TV. Working on android pie .You...       5
# 1     At this price point, the TV is good to have wi...       5
# 2     A very nice Tv with many adjustments and a bes...       5
# 3     OnePlus always brings to us all those high end...       5
# 4     Thank you Flipkart amazing product 1+ TV new m...       5
# ...                                                 ...     ...
# 8190   Just go for it ...best in this price range ...!!       5
# 8191                                               GOOD       4
# 8192  Very nice TV 👍👍It is a very good tv satisfied ...       5
# 8193  Absolutely tremendous ! Just go ahead and get ...       5
# 8194  Excellent Product By Realme.\nPicture Quality ...       5
#
# [8195 rows x 2 columns]

# %%
df=pd.read_csv("review_data")
df
# Out:
#        Unnamed: 0                                       full_reviews  ratings
# 0               0  First of all thanks to flipkart for excellent ...        2
# 1               1  overall good product, mobile colour is good i ...        5
# 2               2  This mobile has good features but battery does...        4
# 3               3  I GOT THIS PHONE WITH SUPERB EXCHANGE DEAL\n\n...        5
# 4               4  I gift this to my mom. The joy in her eyes tel...        5
# ...           ...                                                ...      ...
# 11963       11963                                     budjet tv good        5
# 11964       11964                                  Value for product        5
# 11965       11965                                          Excellent        5
# 11966       11966  Best among the market at this price range. Uni...        4
# 11967       11967  It's simply great tv in its price segments\nLo...        5
#
# [11968 rows x 3 columns]

# %%
df.drop("Unnamed: 0", axis=1,inplace=True)
df
# Out:
#                                             full_reviews  ratings
# 0      First of all thanks to flipkart for excellent ...        2
# 1      overall good product, mobile colour is good i ...        5
# 2      This mobile has good features but battery does...        4
# 3      I GOT THIS PHONE WITH SUPERB EXCHANGE DEAL\n\n...        5
# 4      I gift this to my mom. The joy in her eyes tel...        5
# ...                                                  ...      ...
# 11963                                     budjet tv good        5
# 11964                                  Value for product        5
# 11965                                          Excellent        5
# 11966  Best among the market at this price range. Uni...        4
# 11967  It's simply great tv in its price segments\nLo...        5
#
# [11968 rows x 2 columns]

# %%
frames = [df, df1]
  
result = pd.concat(frames)
display(result)
# Out:
#                                            full_reviews ratings
# 0     First of all thanks to flipkart for excellent ...       2
# 1     overall good product, mobile colour is good i ...       5
# 2     This mobile has good features but battery does...       4
# 3     I GOT THIS PHONE WITH SUPERB EXCHANGE DEAL\n\n...       5
# 4     I gift this to my mom. The joy in her eyes tel...       5
# ...                                                 ...     ...
# 8190   Just go for it ...best in this price range ...!!       5
# 8191                                               GOOD       4
# 8192  Very nice TV 👍👍It is a very good tv satisfied ...       5
# 8193  Absolutely tremendous ! Just go ahead and get ...       5
# 8194  Excellent Product By Realme.\nPicture Quality ...       5
#
# [20163 rows x 2 columns]

# %%
result.head()
# Out:
#                                         full_reviews ratings
# 0  First of all thanks to flipkart for excellent ...       2
# 1  overall good product, mobile colour is good i ...       5
# 2  This mobile has good features but battery does...       4
# 3  I GOT THIS PHONE WITH SUPERB EXCHANGE DEAL\n\n...       5
# 4  I gift this to my mom. The joy in her eyes tel...       5

# %%
result.to_csv("final_review_data")

# %%
result.to_csv("review_rating_data")

# %%
file_name = 'review_rating_data.xlsx'
result.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
